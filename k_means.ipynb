# %%
import numpy as np
import pandas as pd
import re

import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import logging

from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# %%
tweets = []
with open('usnewshealth.txt', 'r') as file:
    for line in file:
        tweets.append(line.strip())

print(f"Total number of tweets: {len(tweets)}")
print("\nTweets:")
for i, tweet in enumerate(tweets[:10]):
    print(f"Tweet {i+1}: {tweet}")
# Out:
# Total number of tweets: 1400
#
# Tweets:
# Tweet 1: 586278450392133633|Thu Apr 09 21:24:09 +0000 2015|Planning to hire a personal trainer? Read these 7 tips first: http://ow.ly/LpxFq
# Tweet 2: 586260156155043843|Thu Apr 09 20:11:28 +0000 2015|RT @AnnaMedaris: Any dads out their who struggled w/ #depression or #anxiety after their kid was born? Let's talk! amiller[at]usnews[dot]co…
# Tweet 3: 586248551811932160|Thu Apr 09 19:25:21 +0000 2015|America's problem with diabetes in one map: http://ow.ly/LoXQG  by @leonardkl @Lindzcook http://pbs.twimg.com/media/CCLF85lW8AAVP4Z.png
# Tweet 4: 586229697165586432|Thu Apr 09 18:10:26 +0000 2015|Think water &amp; fiber will cure your constipation? Unlikely. Here's why: http://ow.ly/LoBLH
# Tweet 5: 586215972731822080|Thu Apr 09 17:15:53 +0000 2015|About to lose it? Here, try one of these office-approved #relaxation exercises: http://ow.ly/LoBkH #stress
# Tweet 6: 586202004583768064|Thu Apr 09 16:20:23 +0000 2015|Should you get your baby's DNA decoded? http://ow.ly/Loypz #genetics
# Tweet 7: 586189609865994242|Thu Apr 09 15:31:08 +0000 2015|3 easy ways to eliminate work #stress: http://ow.ly/Lownl via @USNewsCareers
# Tweet 8: 586176873153110016|Thu Apr 09 14:40:31 +0000 2015|7 steps for choosing &amp; keeping the right personal trainer: http://ow.ly/Lod4r by @ElizabethRenter #personaltraining
# Tweet 9: 586160615019909121|Thu Apr 09 13:35:55 +0000 2015|Getting ready for bikini season? Don't. @kristinkirkpat with the "anti-bikini season #diet" http://ow.ly/Lo7Eu
# Tweet 10: 585988063731519488|Thu Apr 09 02:10:16 +0000 2015|There's a reason you're still fat. In fact, 6 of them. http://ow.ly/LmFLs #weightloss

# %%
def clean_tweet(tweet_text):
    # Remove tweet id and timestamp
    parts = tweet_text.split('|', 2)
    if len(parts) > 2:
        content = parts[2]
    else:
        content = tweet_text

    # Remove words with @
    content = re.sub(r'@\w+', '', content)

    # Remove URLs
    content = re.sub(r'http\S+|www\S+', '', content)

    # Remove hashtag but keep word
    content = re.sub(r'#', '', content)

    # Convert to lowercase
    content = content.lower()

    # Remove special characters
    content = re.sub(r'[^a-z0-9\s]', '', content)

    return content.strip()

print("Tweets Cleaned")
# Out:
# Tweets Cleaned

# %%
cleaned_tweets = [clean_tweet(tweet) for tweet in tweets]

print("Tweets:")
for i, tweet in enumerate(cleaned_tweets[:10]):
    print(f"Tweet {i+1}: {tweet}")
# Out:
# Tweets:
# Tweet 1: planning to hire a personal trainer read these 7 tips first
# Tweet 2: rt  any dads out their who struggled w depression or anxiety after their kid was born lets talk amilleratusnewsdotco
# Tweet 3: americas problem with diabetes in one map   by
# Tweet 4: think water amp fiber will cure your constipation unlikely heres why
# Tweet 5: about to lose it here try one of these officeapproved relaxation exercises  stress
# Tweet 6: should you get your babys dna decoded  genetics
# Tweet 7: 3 easy ways to eliminate work stress  via
# Tweet 8: 7 steps for choosing amp keeping the right personal trainer  by  personaltraining
# Tweet 9: getting ready for bikini season dont  with the antibikini season diet
# Tweet 10: theres a reason youre still fat in fact 6 of them  weightloss

# %%
def jaccard_distance(s1, s2):
    # Turn tweets into sets of words
    words1 = set(s1.split())
    words2 = set(s2.split())

    # Find intersection and union of the sets
    intersection = len(words1.intersection(words2))
    union = len(words1.union(words2))

    # Empty set
    if union == 0:
        return 0.0

    # Calculate Jaccard Distance
    jaccard_similarity = intersection / union
    jaccard_dist = 1 - jaccard_similarity
    return jaccard_dist

# %%
num_tweets = len(cleaned_tweets)
jaccard_matrix = np.zeros((num_tweets, num_tweets))

for i in range(num_tweets):
    for j in range(i, num_tweets):
        dist = jaccard_distance(cleaned_tweets[i], cleaned_tweets[j])
        jaccard_matrix[i, j] = dist
        jaccard_matrix[j, i] = dist

print(f"Jaccard distance matrix of shape: {jaccard_matrix.shape}")
print("\nBlock of the Jaccard distance matrix:")
display(pd.DataFrame(jaccard_matrix[:10, :10],
                     columns=[f"Tweet {k+1}" for k in range(10)],
                     index=[f"Tweet {k+1}" for k in range(10)]))
# Out:
# Jaccard distance matrix of shape: (1400, 1400)
#
# Block of the Jaccard distance matrix:
#            Tweet 1  Tweet 2   Tweet 3   Tweet 4   Tweet 5   Tweet 6   Tweet 7  \
# Tweet 1   0.000000      1.0  1.000000  1.000000  0.909091  1.000000  0.944444
# Tweet 2   1.000000      0.0  1.000000  1.000000  1.000000  1.000000  1.000000
# Tweet 3   1.000000      1.0  0.000000  1.000000  0.950000  1.000000  1.000000
# Tweet 4   1.000000      1.0  1.000000  0.000000  1.000000  0.944444  1.000000
# Tweet 5   0.909091      1.0  0.950000  1.000000  0.000000  1.000000  0.894737
# Tweet 6   1.000000      1.0  1.000000  0.944444  1.000000  0.000000  1.000000
# Tweet 7   0.944444      1.0  1.000000  1.000000  0.894737  1.000000  0.000000
# Tweet 8   0.850000      1.0  0.947368  0.954545  1.000000  1.000000  1.000000
# Tweet 9   1.000000      1.0  0.941176  1.000000  1.000000  1.000000  1.000000
# Tweet 10  0.954545      1.0  0.947368  1.000000  0.958333  1.000000  1.000000
#
#            Tweet 8   Tweet 9  Tweet 10
# Tweet 1   0.850000  1.000000  0.954545
# Tweet 2   1.000000  1.000000  1.000000
# Tweet 3   0.947368  0.941176  0.947368
# Tweet 4   0.954545  1.000000  1.000000
# Tweet 5   1.000000  1.000000  0.958333
# Tweet 6   1.000000  1.000000  1.000000
# Tweet 7   1.000000  1.000000  1.000000
# Tweet 8   0.000000  0.900000  1.000000
# Tweet 9   0.900000  0.000000  1.000000
# Tweet 10  1.000000  1.000000  0.000000

# %%
def initialize_centroids(data_points, k):
    num_data_points = len(data_points)
    if k > num_data_points:
        k = num_data_points

    # k random tweets selected as centroids
    centroid_indices = np.random.choice(num_data_points, k, replace=False)
    return centroid_indices

# %%
def assign_to_clusters(jaccard_matrix, centroid_indices, num_data_points):
    clusters = []

    for i in range(num_data_points):
        min_distance = float('inf')
        closest_centroid_index = -1

        for centroid_id_in_list, centroid_data_id in enumerate(centroid_indices):
            distance = jaccard_matrix[i, centroid_data_id]
            if distance < min_distance:
                min_distance = distance
                closest_centroid_index = centroid_id_in_list
        clusters.append(closest_centroid_index)
    return np.array(clusters)

# %%
def update_centroids(jaccard_matrix, clusters, num_clusters, old_centroid_indices):
    new_centroid_indices = []
    for k in range(num_clusters):
        # Find all data points assigned to the current cluster k
        cluster_members_indices = np.where(clusters == k)[0]

        if len(cluster_members_indices) == 0:
            # If a cluster is empty, keep the old centroid
            new_centroid_indices.append(old_centroid_indices[k])
            continue

        min_sum_distance = float('inf')
        current_centroid_candidate_id = -1

        # Iterate through each data point in the cluster as a potential new centroid
        for i in cluster_members_indices:
            sum_distance = 0.0
            # Calculate the sum of distances from data point to all other points in the cluster
            for j in cluster_members_indices:
                sum_distance += jaccard_matrix[i, j]

            # If data point has smaller sum of distances, it becomes new centroid
            if sum_distance < min_sum_distance:
                min_sum_distance = sum_distance
                current_centroid_candidate_id = i

        new_centroid_indices.append(current_centroid_candidate_id)

    return np.array(new_centroid_indices)

# %%
def k_centroids(jaccard_matrix, num_clusters, max_iterations=100):
    num_data_points = jaccard_matrix.shape[0]

    # Initialize centroids
    final_centroids = initialize_centroids(range(num_data_points), num_clusters)

    for iteration in range(max_iterations):
        clusters = assign_to_clusters(jaccard_matrix, final_centroids, num_data_points)
        old_centroids = np.copy(final_centroids)

        # Update centroids
        final_centroids = update_centroids(jaccard_matrix, clusters, num_clusters, old_centroids)

        # Check if centroids converge
        if np.array_equal(final_centroids, old_centroids):
            break

    return clusters, final_centroids

# %%
def calculate_sse(jaccard_matrix, final_clusters, final_centroids):
    sse = 0.0
    num_data_points = jaccard_matrix.shape[0]

    for i in range(num_data_points):
        # Get cluster from data point
        cluster_id = final_clusters[i]

        # Get centroid id from cluster
        centroid_data_id = final_centroids[cluster_id]

        # Get distance between data point and centroid
        distance = jaccard_matrix[i, centroid_data_id]

        # Add squared distance to SSE
        sse += (distance ** 2)

    return sse

# %%
k_values = [1, 10, 50, 100, 500]

# %%
sse_values = []
cluster_size_info = []

for k_val in k_values:
    print(f"\nK = {k_val}")

    final_clusters, final_centroids = k_centroids(jaccard_matrix, k_val)

    # Calculate SSE
    sse = calculate_sse(jaccard_matrix, final_clusters, final_centroids)
    sse_values.append(sse)
    print(f"SSE: {sse:.4f}")

    # Count the number of data points in each cluster
    cluster_counts = np.bincount(final_clusters)
    current_k_cluster_sizes = {f"Cluster {i+1}": count for i, count in enumerate(cluster_counts)}
    cluster_size_info.append(current_k_cluster_sizes)

    print("Number of tweets for each cluster:")
    for i, count in enumerate(cluster_counts):
        if i < len(final_centroids):
            print(f"Cluster {i+1}: {count} tweets")
# Out:
# K = 1
# SSE: 1209.2106
# Number of tweets for each cluster:
# Cluster 1: 1400 tweets
#
# K = 10
# SSE: 1076.5593
# Number of tweets for each cluster:
# Cluster 1: 118 tweets
# Cluster 2: 66 tweets
# Cluster 3: 48 tweets
# Cluster 4: 61 tweets
# Cluster 5: 116 tweets
# Cluster 6: 56 tweets
# Cluster 7: 240 tweets
# Cluster 8: 270 tweets
# Cluster 9: 357 tweets
# Cluster 10: 68 tweets
#
# K = 50
# SSE: 966.7508
# Number of tweets for each cluster:
# Cluster 1: 44 tweets
# Cluster 2: 14 tweets
# Cluster 3: 9 tweets
# Cluster 4: 46 tweets
# Cluster 5: 10 tweets
# Cluster 6: 27 tweets
# Cluster 7: 26 tweets
# Cluster 8: 46 tweets
# Cluster 9: 28 tweets
# Cluster 10: 38 tweets
# Cluster 11: 7 tweets
# Cluster 12: 17 tweets
# Cluster 13: 14 tweets
# Cluster 14: 101 tweets
# Cluster 15: 5 tweets
# Cluster 16: 5 tweets
# Cluster 17: 5 tweets
# Cluster 18: 76 tweets
# Cluster 19: 32 tweets
# Cluster 20: 25 tweets
# Cluster 21: 9 tweets
# Cluster 22: 40 tweets
# Cluster 23: 14 tweets
# Cluster 24: 12 tweets
# Cluster 25: 18 tweets
# Cluster 26: 42 tweets
# Cluster 27: 8 tweets
# Cluster 28: 55 tweets
# Cluster 29: 43 tweets
# Cluster 30: 30 tweets
# Cluster 31: 7 tweets
# Cluster 32: 9 tweets
# Cluster 33: 45 tweets
# Cluster 34: 28 tweets
# Cluster 35: 20 tweets
# Cluster 36: 14 tweets
# Cluster 37: 24 tweets
# Cluster 38: 10 tweets
# Cluster 39: 33 tweets
# Cluster 40: 63 tweets
# Cluster 41: 36 tweets
# Cluster 42: 59 tweets
# Cluster 43: 28 tweets
# Cluster 44: 17 tweets
# Cluster 45: 15 tweets
# Cluster 46: 20 tweets
# Cluster 47: 77 tweets
# Cluster 48: 8 tweets
# Cluster 49: 20 tweets
# Cluster 50: 21 tweets
#
# K = 100
# SSE: 871.1505
# Number of tweets for each cluster:
# Cluster 1: 1 tweets
# Cluster 2: 57 tweets
# Cluster 3: 20 tweets
# Cluster 4: 4 tweets
# Cluster 5: 4 tweets
# Cluster 6: 31 tweets
# Cluster 7: 8 tweets
# Cluster 8: 20 tweets
# Cluster 9: 47 tweets
# Cluster 10: 13 tweets
# Cluster 11: 29 tweets
# Cluster 12: 3 tweets
# Cluster 13: 5 tweets
# Cluster 14: 2 tweets
# Cluster 15: 18 tweets
# Cluster 16: 16 tweets
# Cluster 17: 6 tweets
# Cluster 18: 16 tweets
# Cluster 19: 28 tweets
# Cluster 20: 30 tweets
# Cluster 21: 2 tweets
# Cluster 22: 14 tweets
# Cluster 23: 13 tweets
# Cluster 24: 15 tweets
# Cluster 25: 46 tweets
# Cluster 26: 4 tweets
# Cluster 27: 6 tweets
# Cluster 28: 16 tweets
# Cluster 29: 19 tweets
# Cluster 30: 31 tweets
# Cluster 31: 7 tweets
# Cluster 32: 8 tweets
# Cluster 33: 5 tweets
# Cluster 34: 3 tweets
# Cluster 35: 10 tweets
# Cluster 36: 9 tweets
# Cluster 37: 15 tweets
# Cluster 38: 15 tweets
# Cluster 39: 11 tweets
# Cluster 40: 12 tweets
# Cluster 41: 26 tweets
# Cluster 42: 8 tweets
# Cluster 43: 23 tweets
# Cluster 44: 7 tweets
# Cluster 45: 21 tweets
# Cluster 46: 18 tweets
# Cluster 47: 15 tweets
# Cluster 48: 18 tweets
# Cluster 49: 5 tweets
# Cluster 50: 3 tweets
# Cluster 51: 19 tweets
# Cluster 52: 24 tweets
# Cluster 53: 10 tweets
# Cluster 54: 4 tweets
# Cluster 55: 13 tweets
# Cluster 56: 18 tweets
# Cluster 57: 10 tweets
# Cluster 58: 13 tweets
# Cluster 59: 3 tweets
# Cluster 60: 6 tweets
# Cluster 61: 24 tweets
# Cluster 62: 29 tweets
# Cluster 63: 16 tweets
# Cluster 64: 36 tweets
# Cluster 65: 17 tweets
# Cluster 66: 28 tweets
# Cluster 67: 4 tweets
# Cluster 68: 20 tweets
# Cluster 69: 6 tweets
# Cluster 70: 21 tweets
# Cluster 71: 10 tweets
# Cluster 72: 29 tweets
# Cluster 73: 24 tweets
# Cluster 74: 16 tweets
# Cluster 75: 5 tweets
# Cluster 76: 9 tweets
# Cluster 77: 6 tweets
# Cluster 78: 11 tweets
# Cluster 79: 2 tweets
# Cluster 80: 5 tweets
# Cluster 81: 8 tweets
# Cluster 82: 3 tweets
# Cluster 83: 31 tweets
# Cluster 84: 8 tweets
# Cluster 85: 7 tweets
# Cluster 86: 3 tweets
# Cluster 87: 8 tweets
# Cluster 88: 17 tweets
# Cluster 89: 15 tweets
# Cluster 90: 9 tweets
# Cluster 91: 10 tweets
# Cluster 92: 12 tweets
# Cluster 93: 10 tweets
# Cluster 94: 6 tweets
# Cluster 95: 12 tweets
# Cluster 96: 14 tweets
# Cluster 97: 7 tweets
# Cluster 98: 4 tweets
# Cluster 99: 6 tweets
# Cluster 100: 9 tweets
#
# K = 500
# SSE: 509.1373
# Number of tweets for each cluster:
# Cluster 1: 6 tweets
# Cluster 2: 2 tweets
# Cluster 3: 5 tweets
# Cluster 4: 3 tweets
# Cluster 5: 7 tweets
# Cluster 6: 1 tweets
# Cluster 7: 8 tweets
# Cluster 8: 3 tweets
# Cluster 9: 2 tweets
# Cluster 10: 4 tweets
# Cluster 11: 10 tweets
# Cluster 12: 1 tweets
# Cluster 13: 4 tweets
# Cluster 14: 2 tweets
# Cluster 15: 4 tweets
# Cluster 16: 1 tweets
# Cluster 17: 3 tweets
# Cluster 18: 1 tweets
# Cluster 19: 1 tweets
# Cluster 20: 3 tweets
# Cluster 21: 3 tweets
# Cluster 22: 3 tweets
# Cluster 23: 1 tweets
# Cluster 24: 1 tweets
# Cluster 25: 7 tweets
# Cluster 26: 2 tweets
# Cluster 27: 3 tweets
# Cluster 28: 2 tweets
# Cluster 29: 2 tweets
# Cluster 30: 3 tweets
# Cluster 31: 1 tweets
# Cluster 32: 1 tweets
# Cluster 33: 4 tweets
# Cluster 34: 5 tweets
# Cluster 35: 7 tweets
# Cluster 36: 3 tweets
# Cluster 37: 9 tweets
# Cluster 38: 5 tweets
# Cluster 39: 1 tweets
# Cluster 40: 1 tweets
# Cluster 41: 3 tweets
# Cluster 42: 3 tweets
# Cluster 43: 1 tweets
# Cluster 44: 3 tweets
# Cluster 45: 2 tweets
# Cluster 46: 2 tweets
# Cluster 47: 4 tweets
# Cluster 48: 4 tweets
# Cluster 49: 2 tweets
# Cluster 50: 1 tweets
# Cluster 51: 1 tweets
# Cluster 52: 3 tweets
# Cluster 53: 2 tweets
# Cluster 54: 2 tweets
# Cluster 55: 2 tweets
# Cluster 56: 1 tweets
# Cluster 57: 3 tweets
# Cluster 58: 2 tweets
# Cluster 59: 3 tweets
# Cluster 60: 10 tweets
# Cluster 61: 5 tweets
# Cluster 62: 2 tweets
# Cluster 63: 7 tweets
# Cluster 64: 3 tweets
# Cluster 65: 1 tweets
# Cluster 66: 4 tweets
# Cluster 67: 2 tweets
# Cluster 68: 1 tweets
# Cluster 69: 1 tweets
# Cluster 70: 9 tweets
# Cluster 71: 4 tweets
# Cluster 72: 1 tweets
# Cluster 73: 1 tweets
# Cluster 74: 2 tweets
# Cluster 75: 1 tweets
# Cluster 76: 1 tweets
# Cluster 77: 3 tweets
# Cluster 78: 1 tweets
# Cluster 79: 1 tweets
# Cluster 80: 2 tweets
# Cluster 81: 3 tweets
# Cluster 82: 2 tweets
# Cluster 83: 3 tweets
# Cluster 84: 11 tweets
# Cluster 85: 3 tweets
# Cluster 86: 3 tweets
# Cluster 87: 3 tweets
# Cluster 88: 10 tweets
# Cluster 89: 5 tweets
# Cluster 90: 6 tweets
# Cluster 91: 7 tweets
# Cluster 92: 4 tweets
# Cluster 93: 9 tweets
# Cluster 94: 1 tweets
# Cluster 95: 5 tweets
# Cluster 96: 1 tweets
# Cluster 97: 6 tweets
# Cluster 98: 1 tweets
# Cluster 99: 4 tweets
# Cluster 100: 5 tweets
# Cluster 101: 2 tweets
# Cluster 102: 4 tweets
# Cluster 103: 4 tweets
# Cluster 104: 4 tweets
# Cluster 105: 2 tweets
# Cluster 106: 2 tweets
# Cluster 107: 3 tweets
# Cluster 108: 5 tweets
# Cluster 109: 1 tweets
# Cluster 110: 1 tweets
# Cluster 111: 1 tweets
# Cluster 112: 1 tweets
# Cluster 113: 3 tweets
# Cluster 114: 4 tweets
# Cluster 115: 3 tweets
# Cluster 116: 2 tweets
# Cluster 117: 6 tweets
# Cluster 118: 1 tweets
# Cluster 119: 1 tweets
# Cluster 120: 2 tweets
# Cluster 121: 1 tweets
# Cluster 122: 1 tweets
# Cluster 123: 1 tweets
# Cluster 124: 2 tweets
# Cluster 125: 1 tweets
# Cluster 126: 3 tweets
# Cluster 127: 4 tweets
# Cluster 128: 1 tweets
# Cluster 129: 2 tweets
# Cluster 130: 4 tweets
# Cluster 131: 5 tweets
# Cluster 132: 3 tweets
# Cluster 133: 2 tweets
# Cluster 134: 1 tweets
# Cluster 135: 2 tweets
# Cluster 136: 3 tweets
# Cluster 137: 4 tweets
# Cluster 138: 1 tweets
# Cluster 139: 4 tweets
# Cluster 140: 3 tweets
# Cluster 141: 7 tweets
# Cluster 142: 1 tweets
# Cluster 143: 3 tweets
# Cluster 144: 6 tweets
# Cluster 145: 5 tweets
# Cluster 146: 1 tweets
# Cluster 147: 4 tweets
# Cluster 148: 1 tweets
# Cluster 149: 3 tweets
# Cluster 150: 1 tweets
# Cluster 151: 1 tweets
# Cluster 152: 2 tweets
# Cluster 153: 2 tweets
# Cluster 154: 6 tweets
# Cluster 155: 5 tweets
# Cluster 156: 1 tweets
# Cluster 157: 3 tweets
# Cluster 158: 1 tweets
# Cluster 159: 6 tweets
# Cluster 160: 1 tweets
# Cluster 161: 1 tweets
# Cluster 162: 6 tweets
# Cluster 163: 4 tweets
# Cluster 164: 1 tweets
# Cluster 165: 1 tweets
# Cluster 166: 1 tweets
# Cluster 167: 1 tweets
# Cluster 168: 4 tweets
# Cluster 169: 4 tweets
# Cluster 170: 1 tweets
# Cluster 171: 2 tweets
# Cluster 172: 2 tweets
# Cluster 173: 2 tweets
# Cluster 174: 4 tweets
# Cluster 175: 5 tweets
# Cluster 176: 4 tweets
# Cluster 177: 1 tweets
# Cluster 178: 2 tweets
# Cluster 179: 3 tweets
# Cluster 180: 1 tweets
# Cluster 181: 1 tweets
# Cluster 182: 2 tweets
# Cluster 183: 1 tweets
# Cluster 184: 4 tweets
# Cluster 185: 6 tweets
# Cluster 186: 3 tweets
# Cluster 187: 3 tweets
# Cluster 188: 3 tweets
# Cluster 189: 1 tweets
# Cluster 190: 3 tweets
# Cluster 191: 3 tweets
# Cluster 192: 3 tweets
# Cluster 193: 3 tweets
# Cluster 194: 7 tweets
# Cluster 195: 2 tweets
# Cluster 196: 2 tweets
# Cluster 197: 4 tweets
# Cluster 198: 3 tweets
# Cluster 199: 1 tweets
# Cluster 200: 6 tweets
# Cluster 201: 1 tweets
# Cluster 202: 2 tweets
# Cluster 203: 6 tweets
# Cluster 204: 2 tweets
# Cluster 205: 1 tweets
# Cluster 206: 4 tweets
# Cluster 207: 4 tweets
# Cluster 208: 1 tweets
# Cluster 209: 4 tweets
# Cluster 210: 3 tweets
# Cluster 211: 8 tweets
# Cluster 212: 1 tweets
# Cluster 213: 3 tweets
# Cluster 214: 8 tweets
# Cluster 215: 3 tweets
# Cluster 216: 2 tweets
# Cluster 217: 1 tweets
# Cluster 218: 2 tweets
# Cluster 219: 3 tweets
# Cluster 220: 1 tweets
# Cluster 221: 1 tweets
# Cluster 222: 3 tweets
# Cluster 223: 3 tweets
# Cluster 224: 7 tweets
# Cluster 225: 4 tweets
# Cluster 226: 3 tweets
# Cluster 227: 3 tweets
# Cluster 228: 3 tweets
# Cluster 229: 3 tweets
# Cluster 230: 1 tweets
# Cluster 231: 1 tweets
# Cluster 232: 1 tweets
# Cluster 233: 1 tweets
# Cluster 234: 4 tweets
# Cluster 235: 1 tweets
# Cluster 236: 5 tweets
# Cluster 237: 1 tweets
# Cluster 238: 1 tweets
# Cluster 239: 3 tweets
# Cluster 240: 1 tweets
# Cluster 241: 3 tweets
# Cluster 242: 6 tweets
# Cluster 243: 1 tweets
# Cluster 244: 1 tweets
# Cluster 245: 7 tweets
# Cluster 246: 7 tweets
# Cluster 247: 3 tweets
# Cluster 248: 3 tweets
# Cluster 249: 1 tweets
# Cluster 250: 2 tweets
# Cluster 251: 4 tweets
# Cluster 252: 3 tweets
# Cluster 253: 3 tweets
# Cluster 254: 2 tweets
# Cluster 255: 1 tweets
# Cluster 256: 2 tweets
# Cluster 257: 6 tweets
# Cluster 258: 2 tweets
# Cluster 259: 5 tweets
# Cluster 260: 3 tweets
# Cluster 261: 1 tweets
# Cluster 262: 1 tweets
# Cluster 263: 3 tweets
# Cluster 264: 1 tweets
# Cluster 265: 2 tweets
# Cluster 266: 1 tweets
# Cluster 267: 4 tweets
# Cluster 268: 4 tweets
# Cluster 269: 3 tweets
# Cluster 270: 1 tweets
# Cluster 271: 2 tweets
# Cluster 272: 4 tweets
# Cluster 273: 4 tweets
# Cluster 274: 1 tweets
# Cluster 275: 5 tweets
# Cluster 276: 1 tweets
# Cluster 277: 1 tweets
# Cluster 278: 2 tweets
# Cluster 279: 3 tweets
# Cluster 280: 1 tweets
# Cluster 281: 3 tweets
# Cluster 282: 1 tweets
# Cluster 283: 2 tweets
# Cluster 284: 1 tweets
# Cluster 285: 1 tweets
# Cluster 286: 1 tweets
# Cluster 287: 5 tweets
# Cluster 288: 1 tweets
# Cluster 289: 1 tweets
# Cluster 290: 1 tweets
# Cluster 291: 4 tweets
# Cluster 292: 5 tweets
# Cluster 293: 1 tweets
# Cluster 294: 3 tweets
# Cluster 295: 1 tweets
# Cluster 296: 4 tweets
# Cluster 297: 6 tweets
# Cluster 298: 9 tweets
# Cluster 299: 6 tweets
# Cluster 300: 2 tweets
# Cluster 301: 1 tweets
# Cluster 302: 3 tweets
# Cluster 303: 1 tweets
# Cluster 304: 1 tweets
# Cluster 305: 4 tweets
# Cluster 306: 3 tweets
# Cluster 307: 4 tweets
# Cluster 308: 1 tweets
# Cluster 309: 2 tweets
# Cluster 310: 4 tweets
# Cluster 311: 1 tweets
# Cluster 312: 0 tweets
# Cluster 313: 2 tweets
# Cluster 314: 6 tweets
# Cluster 315: 4 tweets
# Cluster 316: 4 tweets
# Cluster 317: 1 tweets
# Cluster 318: 3 tweets
# Cluster 319: 1 tweets
# Cluster 320: 4 tweets
# Cluster 321: 6 tweets
# Cluster 322: 1 tweets
# Cluster 323: 3 tweets
# Cluster 324: 3 tweets
# Cluster 325: 1 tweets
# Cluster 326: 2 tweets
# Cluster 327: 6 tweets
# Cluster 328: 1 tweets
# Cluster 329: 3 tweets
# Cluster 330: 8 tweets
# Cluster 331: 1 tweets
# Cluster 332: 1 tweets
# Cluster 333: 5 tweets
# Cluster 334: 1 tweets
# Cluster 335: 1 tweets
# Cluster 336: 1 tweets
# Cluster 337: 1 tweets
# Cluster 338: 1 tweets
# Cluster 339: 12 tweets
# Cluster 340: 2 tweets
# Cluster 341: 1 tweets
# Cluster 342: 1 tweets
# Cluster 343: 2 tweets
# Cluster 344: 1 tweets
# Cluster 345: 1 tweets
# Cluster 346: 3 tweets
# Cluster 347: 3 tweets
# Cluster 348: 3 tweets
# Cluster 349: 1 tweets
# Cluster 350: 1 tweets
# Cluster 351: 1 tweets
# Cluster 352: 1 tweets
# Cluster 353: 2 tweets
# Cluster 354: 1 tweets
# Cluster 355: 2 tweets
# Cluster 356: 5 tweets
# Cluster 357: 3 tweets
# Cluster 358: 2 tweets
# Cluster 359: 6 tweets
# Cluster 360: 1 tweets
# Cluster 361: 3 tweets
# Cluster 362: 2 tweets
# Cluster 363: 2 tweets
# Cluster 364: 1 tweets
# Cluster 365: 1 tweets
# Cluster 366: 1 tweets
# Cluster 367: 1 tweets
# Cluster 368: 6 tweets
# Cluster 369: 3 tweets
# Cluster 370: 1 tweets
# Cluster 371: 2 tweets
# Cluster 372: 1 tweets
# Cluster 373: 4 tweets
# Cluster 374: 8 tweets
# Cluster 375: 1 tweets
# Cluster 376: 1 tweets
# Cluster 377: 5 tweets
# Cluster 378: 3 tweets
# Cluster 379: 3 tweets
# Cluster 380: 3 tweets
# Cluster 381: 3 tweets
# Cluster 382: 1 tweets
# Cluster 383: 1 tweets
# Cluster 384: 4 tweets
# Cluster 385: 6 tweets
# Cluster 386: 1 tweets
# Cluster 387: 1 tweets
# Cluster 388: 1 tweets
# Cluster 389: 1 tweets
# Cluster 390: 2 tweets
# Cluster 391: 1 tweets
# Cluster 392: 1 tweets
# Cluster 393: 3 tweets
# Cluster 394: 5 tweets
# Cluster 395: 2 tweets
# Cluster 396: 1 tweets
# Cluster 397: 3 tweets
# Cluster 398: 1 tweets
# Cluster 399: 6 tweets
# Cluster 400: 5 tweets
# Cluster 401: 1 tweets
# Cluster 402: 5 tweets
# Cluster 403: 4 tweets
# Cluster 404: 3 tweets
# Cluster 405: 1 tweets
# Cluster 406: 2 tweets
# Cluster 407: 1 tweets
# Cluster 408: 2 tweets
# Cluster 409: 1 tweets
# Cluster 410: 2 tweets
# Cluster 411: 7 tweets
# Cluster 412: 1 tweets
# Cluster 413: 4 tweets
# Cluster 414: 4 tweets
# Cluster 415: 2 tweets
# Cluster 416: 1 tweets
# Cluster 417: 8 tweets
# Cluster 418: 1 tweets
# Cluster 419: 1 tweets
# Cluster 420: 8 tweets
# Cluster 421: 1 tweets
# Cluster 422: 4 tweets
# Cluster 423: 3 tweets
# Cluster 424: 3 tweets
# Cluster 425: 4 tweets
# Cluster 426: 1 tweets
# Cluster 427: 4 tweets
# Cluster 428: 2 tweets
# Cluster 429: 3 tweets
# Cluster 430: 2 tweets
# Cluster 431: 4 tweets
# Cluster 432: 1 tweets
# Cluster 433: 4 tweets
# Cluster 434: 1 tweets
# Cluster 435: 4 tweets
# Cluster 436: 5 tweets
# Cluster 437: 1 tweets
# Cluster 438: 1 tweets
# Cluster 439: 1 tweets
# Cluster 440: 5 tweets
# Cluster 441: 1 tweets
# Cluster 442: 2 tweets
# Cluster 443: 1 tweets
# Cluster 444: 1 tweets
# Cluster 445: 4 tweets
# Cluster 446: 1 tweets
# Cluster 447: 5 tweets
# Cluster 448: 1 tweets
# Cluster 449: 3 tweets
# Cluster 450: 4 tweets
# Cluster 451: 5 tweets
# Cluster 452: 3 tweets
# Cluster 453: 1 tweets
# Cluster 454: 3 tweets
# Cluster 455: 3 tweets
# Cluster 456: 1 tweets
# Cluster 457: 6 tweets
# Cluster 458: 7 tweets
# Cluster 459: 1 tweets
# Cluster 460: 5 tweets
# Cluster 461: 3 tweets
# Cluster 462: 3 tweets
# Cluster 463: 3 tweets
# Cluster 464: 1 tweets
# Cluster 465: 4 tweets
# Cluster 466: 1 tweets
# Cluster 467: 1 tweets
# Cluster 468: 1 tweets
# Cluster 469: 1 tweets
# Cluster 470: 2 tweets
# Cluster 471: 5 tweets
# Cluster 472: 1 tweets
# Cluster 473: 1 tweets
# Cluster 474: 2 tweets
# Cluster 475: 2 tweets
# Cluster 476: 8 tweets
# Cluster 477: 1 tweets
# Cluster 478: 1 tweets
# Cluster 479: 3 tweets
# Cluster 480: 1 tweets
# Cluster 481: 4 tweets
# Cluster 482: 3 tweets
# Cluster 483: 5 tweets
# Cluster 484: 3 tweets
# Cluster 485: 2 tweets
# Cluster 486: 1 tweets
# Cluster 487: 1 tweets
# Cluster 488: 3 tweets
# Cluster 489: 1 tweets
# Cluster 490: 1 tweets
# Cluster 491: 3 tweets
# Cluster 492: 5 tweets
# Cluster 493: 4 tweets
# Cluster 494: 1 tweets
# Cluster 495: 2 tweets
# Cluster 496: 5 tweets
# Cluster 497: 1 tweets
# Cluster 498: 3 tweets
# Cluster 499: 0 tweets
# Cluster 500: 2 tweets

# %%
results_data = []

for i, k_val in enumerate(k_values):
    results_data.append({
        'Value of K': k_val,
        'SSE Value': round(sse_values[i], 4),
        'Cluster Sizes': cluster_size_info[i]
    })

results_df = pd.DataFrame(results_data)

# %%
# Write data to log file
logging.basicConfig(filename = 'kmeans.log', level = logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    force = True)

for result in results_data:
    k_value = result['Value of K']
    sse_value = result['SSE Value']
    cluster_sizes = result['Cluster Sizes']

    log_message = f"K Value: {k_value}, SSE: {sse_value:.4f}\n"
    log_message += "Cluster Sizes:\n"
    for cluster, size in cluster_sizes.items():
        log_message += f"{cluster}: {size} tweets\n"

    logging.info(log_message)
